# %%
# %pip install nltk

# %% [markdown]
# # Libraries

# %%
import pandas as pd
import re
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import numpy as np
from pyarabic import araby
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\WalidAlshamrani\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\WalidAlshamrani\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\WalidAlshamrani\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\WalidAlshamrani\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# ### Data Loading

# %%
df = pd.read_csv("AAAA sports_tweets.csv")

# %% [markdown]
# ### Handling missing values

# %%
# Checking if there is any missing values
df = df.replace('NaN', np.nan)
print(df.isnull().sum())
# Out:
# tweet    0
# label    0
# dtype: int64

# %% [markdown]
# ###  Duplicate values removal

# %%
# Checking if there is any duplicate values and removing it
original_count = len(df)

df.drop_duplicates(subset=['tweet'], keep='first', inplace=True)

cleaned_count = len(df)
deleted_count = original_count - cleaned_count

print(f"Original number of tweets: {original_count}")
print(f"Number of duplicate tweets deleted: {cleaned_count}")
print(f"=====================================")
print(f"Number of duplicate tweets deleted: {deleted_count} 🗑️")
# Out:
# Original number of tweets: 3044
# Number of duplicate tweets deleted: 2316
# =====================================
# Number of duplicate tweets deleted: 728 🗑️

# %% [markdown]
# ### Removal of non-Arabic letters and special symbols

# %%
# Cleaning Arabic text by removing non-Arabic characters, and normalizing whitespace
def clean_arabic_text(text):
    text = re.sub(r"[^\u0600-\u06FF\s]", "", text) # Regex to keep Arabic letters (Unicode range 0600-06FF) and spaces
    text = re.sub(r'[^\w\s]', '', text) # Remove special characters and symbols
    text = " ".join(text.split()) # Remove extra whitespaces
    return text

df['cleaned_tweet'] = df['tweet'].apply(clean_arabic_text)

# %% [markdown]
# ###  Emojis removal

# %%
# Removing emojis from tweet
def remove_emojis(text):
    emoji_pattern = re.compile(
        "["
        "\U0001F600-\U0001F64F"  # emoticons
        "\U0001F300-\U0001F5FF"  # symbols & pictographs
        "\U0001F680-\U0001F6FF"  # transport & map symbols
        "\U0001F1E0-\U0001F1FF"  # flags (iOS)
        "\U00002702-\U000027B0"
        "\U000024C2-\U0001F251"
        "]+",
        flags=re.UNICODE,
    )
    return emoji_pattern.sub(r"", text)

df['no_emojis_tweet'] = df['cleaned_tweet'].apply(remove_emojis)

# %% [markdown]
# ### Normalization

# %%
# Function to normalize different forms of Hamza and Alef
def normalize_hamza(text):
  text = text.replace(u"\u0623", u"\u0627")  # Replace Alef with Hamza above to bare Alef
  text = text.replace(u"\u0625", u"\u0627")  # Replace Alef with Hamza below to bare Alef
  text = text.replace(u"\u0624", u"\u0648")  # Replace Waw with Hamza to Waw
  text = text.replace(u"\u0626", u"\u064a")  # Replace Ya with Hamza to Ya
  text = text.replace(u"\u0671", u"\u0627")  # Replace Alef Wasla to bare Alef
  return text

# Apply normalization
df['normalized_tweet'] = df['no_emojis_tweet'].apply(normalize_hamza)

# %% [markdown]
# ### Links removal

# %%
# Removing the links
def remove_links(text):
    text = text.lower()
    text = re.sub(r"http\S+|www\S+|https\S+", '', text, flags=re.MULTILINE) # Remove URLs
    text = re.sub(r'&[a-z]+;', '', text) # Remove HTML entities
    text = re.sub(r"\d+", '', text) # Remove numbers
    return text

df['no_link_tweet'] = df['normalized_tweet'].apply(remove_links)

# %% [markdown]
# ### Tokenization and stop word removal

# %%
# Function to tokenize text and remove Arabic stopwords
def tokenize_tweet(text):
    tokens = word_tokenize(text)
    # Load Arabic stopwords
    stop_words = set(stopwords.words('arabic'))
    # Filter out stopwords
    tokens = [word for word in tokens if word not in stop_words]
    return tokens

df['tokenized_tweet'] = df['no_link_tweet'].apply(tokenize_tweet)

# %% [markdown]
# ### Lemmatization

# %%
# Function to lemmatize tokens using PyArabic
def lemmatize_tweet(tokens):
    if hasattr(araby, 'is_stem'):
        # If the token is not already a stem, apply logic (simplistic check here)
        lemmatized_tokens = [token for token in tokens if not araby.is_stem(token)]
    else:
        lemmatized_tokens = tokens
    return lemmatized_tokens

df['lemmatized_tweet'] = df['tokenized_tweet'].apply(lemmatize_tweet)

# %% [markdown]
# ### Verification and Comparison

# %%
print("\nExample of cleaned tweet:")
for i in range(5):
    print("Original:", df['tweet'][i])
    print("Cleaned:", df['cleaned_tweet'][i])
    print("No emojis:", df['no_emojis_tweet'][i])
    print("Normalized:", df['normalized_tweet'][i])
    print("No Link:", df['no_link_tweet'][i])
    print("Tokenized:", df['tokenized_tweet'][i])
    print("Lemmatized:", df['lemmatized_tweet'][i])
    print("-" * 20)
# Out:
# Example of cleaned tweet:
# Original:  تخيل بس تخيل اعتمد علي غريزمان وموراتا اثنين ولله منتهين الصلاحيه من زمان واحد قدم موسم واحد والثاني انتهي من لم باع النادي نرجع للوسط كوكي ويورنتي كوكي اقسم بالله اعتمد علي كلب ولا اعتمد عليه ويورنتي ماشفنا منو شي من بعد موسم  نرجع للدفاع خمنيز وسافيتش خمنيز حرام يلعب كره قد
# Cleaned: تخيل بس تخيل اعتمد علي غريزمان وموراتا اثنين ولله منتهين الصلاحيه من زمان واحد قدم موسم واحد والثاني انتهي من لم باع النادي نرجع للوسط كوكي ويورنتي كوكي اقسم بالله اعتمد علي كلب ولا اعتمد عليه ويورنتي ماشفنا منو شي من بعد موسم نرجع للدفاع خمنيز وسافيتش خمنيز حرام يلعب كره قد
# No emojis: تخيل بس تخيل اعتمد علي غريزمان وموراتا اثنين ولله منتهين الصلاحيه من زمان واحد قدم موسم واحد والثاني انتهي من لم باع النادي نرجع للوسط كوكي ويورنتي كوكي اقسم بالله اعتمد علي كلب ولا اعتمد عليه ويورنتي ماشفنا منو شي من بعد موسم نرجع للدفاع خمنيز وسافيتش خمنيز حرام يلعب كره قد
# Normalized: تخيل بس تخيل اعتمد علي غريزمان وموراتا اثنين ولله منتهين الصلاحيه من زمان واحد قدم موسم واحد والثاني انتهي من لم باع النادي نرجع للوسط كوكي ويورنتي كوكي اقسم بالله اعتمد علي كلب ولا اعتمد عليه ويورنتي ماشفنا منو شي من بعد موسم نرجع للدفاع خمنيز وسافيتش خمنيز حرام يلعب كره قد
# No Link: تخيل بس تخيل اعتمد علي غريزمان وموراتا اثنين ولله منتهين الصلاحيه من زمان واحد قدم موسم واحد والثاني انتهي من لم باع النادي نرجع للوسط كوكي ويورنتي كوكي اقسم بالله اعتمد علي كلب ولا اعتمد عليه ويورنتي ماشفنا منو شي من بعد موسم نرجع للدفاع خمنيز وسافيتش خمنيز حرام يلعب كره قد
# Tokenized: ['تخيل', 'تخيل', 'اعتمد', 'علي', 'غريزمان', 'وموراتا', 'ولله', 'منتهين', 'الصلاحيه', 'زمان', 'قدم', 'موسم', 'والثاني', 'انتهي', 'باع', 'النادي', 'نرجع', 'للوسط', 'كوكي', 'ويورنتي', 'كوكي', 'اقسم', 'بالله', 'اعتمد', 'علي', 'كلب', 'اعتمد', 'ويورنتي', 'ماشفنا', 'منو', 'شي', 'موسم', 'نرجع', 'للدفاع', 'خمنيز', 'وسافيتش', 'خمنيز', 'حرام', 'يلعب', 'كره']
# Lemmatized: ['تخيل', 'تخيل', 'اعتمد', 'علي', 'غريزمان', 'وموراتا', 'ولله', 'منتهين', 'الصلاحيه', 'زمان', 'قدم', 'موسم', 'والثاني', 'انتهي', 'باع', 'النادي', 'نرجع', 'للوسط', 'كوكي', 'ويورنتي', 'كوكي', 'اقسم', 'بالله', 'اعتمد', 'علي', 'كلب', 'اعتمد', 'ويورنتي', 'ماشفنا', 'منو', 'شي', 'موسم', 'نرجع', 'للدفاع', 'خمنيز', 'وسافيتش', 'خمنيز', 'حرام', 'يلعب', 'كره']
# --------------------
# Original: بطولات في عهد فهد بن نافل خلال سنوات فقط حتي الان دوري أبطال اسيا الدوري السعودي كأس السوبر كأس الملك بطولات وانجازات مسلي ال معمر مع النصر هي التعاقدات مع عجايز اوروبا والجلوس بجانب فهد بن نافل
# Cleaned: بطولات في عهد فهد بن نافل خلال سنوات فقط حتي الان دوري أبطال اسيا الدوري السعودي كأس السوبر كأس الملك بطولات وانجازات مسلي ال معمر مع النصر هي التعاقدات مع عجايز اوروبا والجلوس بجانب فهد بن نافل
# No emojis: بطولات في عهد فهد بن نافل خلال سنوات فقط حتي الان دوري أبطال اسيا الدوري السعودي كأس السوبر كأس الملك بطولات وانجازات مسلي ال معمر مع النصر هي التعاقدات مع عجايز اوروبا والجلوس بجانب فهد بن نافل
# Normalized: بطولات في عهد فهد بن نافل خلال سنوات فقط حتي الان دوري ابطال اسيا الدوري السعودي كاس السوبر كاس الملك بطولات وانجازات مسلي ال معمر مع النصر هي التعاقدات مع عجايز اوروبا والجلوس بجانب فهد بن نافل
# No Link: بطولات في عهد فهد بن نافل خلال سنوات فقط حتي الان دوري ابطال اسيا الدوري السعودي كاس السوبر كاس الملك بطولات وانجازات مسلي ال معمر مع النصر هي التعاقدات مع عجايز اوروبا والجلوس بجانب فهد بن نافل
# Tokenized: ['بطولات', 'عهد', 'فهد', 'بن', 'نافل', 'خلال', 'سنوات', 'فقط', 'حتي', 'الان', 'دوري', 'ابطال', 'اسيا', 'الدوري', 'السعودي', 'كاس', 'السوبر', 'كاس', 'الملك', 'بطولات', 'وانجازات', 'مسلي', 'ال', 'معمر', 'النصر', 'التعاقدات', 'عجايز', 'اوروبا', 'والجلوس', 'بجانب', 'فهد', 'بن', 'نافل']
# Lemmatized: ['بطولات', 'عهد', 'فهد', 'بن', 'نافل', 'خلال', 'سنوات', 'فقط', 'حتي', 'الان', 'دوري', 'ابطال', 'اسيا', 'الدوري', 'السعودي', 'كاس', 'السوبر', 'كاس', 'الملك', 'بطولات', 'وانجازات', 'مسلي', 'ال', 'معمر', 'النصر', 'التعاقدات', 'عجايز', 'اوروبا', 'والجلوس', 'بجانب', 'فهد', 'بن', 'نافل']
# --------------------
# Original: اللي يلعبون زي خدمي ما يستاهلوا التشكيل الاساسي. المباراة مع ضمك انتهت بنتيجة 1-0
# Cleaned: اللي يلعبون زي خدمي ما يستاهلوا التشكيل الاساسي المباراة مع ضمك انتهت بنتيجة
# No emojis: اللي يلعبون زي خدمي ما يستاهلوا التشكيل الاساسي المباراة مع ضمك انتهت بنتيجة
# Normalized: اللي يلعبون زي خدمي ما يستاهلوا التشكيل الاساسي المباراة مع ضمك انتهت بنتيجة
# No Link: اللي يلعبون زي خدمي ما يستاهلوا التشكيل الاساسي المباراة مع ضمك انتهت بنتيجة
# Tokenized: ['اللي', 'يلعبون', 'زي', 'خدمي', 'يستاهلوا', 'التشكيل', 'الاساسي', 'المباراة', 'ضمك', 'انتهت', 'بنتيجة']
# Lemmatized: ['اللي', 'يلعبون', 'زي', 'خدمي', 'يستاهلوا', 'التشكيل', 'الاساسي', 'المباراة', 'ضمك', 'انتهت', 'بنتيجة']
# --------------------
# Original: أداء فاشل من طاقيه اليوم، حسّونّا بالإحباط. المباراة مع الرائد انتهت بنتيجة 1-1
# Cleaned: أداء فاشل من طاقيه اليوم حسونا بالإحباط المباراة مع الرائد انتهت بنتيجة
# No emojis: أداء فاشل من طاقيه اليوم حسونا بالإحباط المباراة مع الرائد انتهت بنتيجة
# Normalized: اداء فاشل من طاقيه اليوم حسونا بالاحباط المباراة مع الرايد انتهت بنتيجة
# No Link: اداء فاشل من طاقيه اليوم حسونا بالاحباط المباراة مع الرايد انتهت بنتيجة
# Tokenized: ['اداء', 'فاشل', 'طاقيه', 'اليوم', 'حسونا', 'بالاحباط', 'المباراة', 'الرايد', 'انتهت', 'بنتيجة']
# Lemmatized: ['اداء', 'فاشل', 'طاقيه', 'اليوم', 'حسونا', 'بالاحباط', 'المباراة', 'الرايد', 'انتهت', 'بنتيجة']
# --------------------
# Original: أداء فاشل من خدمي اليوم، حسّونّا بالإحباط. المباراة مع الهلال انتهت بنتيجة 1-0
# Cleaned: أداء فاشل من خدمي اليوم حسونا بالإحباط المباراة مع الهلال انتهت بنتيجة
# No emojis: أداء فاشل من خدمي اليوم حسونا بالإحباط المباراة مع الهلال انتهت بنتيجة
# Normalized: اداء فاشل من خدمي اليوم حسونا بالاحباط المباراة مع الهلال انتهت بنتيجة
# No Link: اداء فاشل من خدمي اليوم حسونا بالاحباط المباراة مع الهلال انتهت بنتيجة
# Tokenized: ['اداء', 'فاشل', 'خدمي', 'اليوم', 'حسونا', 'بالاحباط', 'المباراة', 'الهلال', 'انتهت', 'بنتيجة']
# Lemmatized: ['اداء', 'فاشل', 'خدمي', 'اليوم', 'حسونا', 'بالاحباط', 'المباراة', 'الهلال', 'انتهت', 'بنتيجة']
# --------------------

# %% [markdown]
# ### Final Output

# %%
# Drop intermediate processing columns to save memory and clean the view
df = df.drop(columns=['tweet', 'cleaned_tweet', 'no_emojis_tweet', 'normalized_tweet','no_link_tweet', 'tokenized_tweet'])

# %%
df['tweet'] = df['lemmatized_tweet'].apply(lambda x: ' '.join(x))

# %%
# Reorder columns for the final output
new_order = ['tweet', 'lemmatized_tweet', 'label']

df = df[new_order]
df
# Out:
#                                                   tweet  \
# 0     تخيل تخيل اعتمد علي غريزمان وموراتا ولله منتهي...
# 1     بطولات عهد فهد بن نافل خلال سنوات فقط حتي الان...
# 2     اللي يلعبون زي خدمي يستاهلوا التشكيل الاساسي ا...
# 3     اداء فاشل طاقيه اليوم حسونا بالاحباط المباراة ...
# 4     اداء فاشل خدمي اليوم حسونا بالاحباط المباراة ا...
# ...                                                 ...
# 3037  مرة ثانية طاقيه يحطمون الآمال لازم حل جذري الم...
# 3039  اخخ يالقهر دايم اذا خسر الهلال ابوي يخليني اضح...
# 3040                          الفيصلي بلا كرامة وخرب شي
# 3041  لربما انك الدوري الاستثناي كنت مرتديا ثوب سبعه...
# 3043  باولينيو باقي وجه تغرد وجه البومه خبر توقيع تا...
#
#                                        lemmatized_tweet label
# 0     [تخيل, تخيل, اعتمد, علي, غريزمان, وموراتا, ولل...  hate
# 1     [بطولات, عهد, فهد, بن, نافل, خلال, سنوات, فقط,...   not
# 2     [اللي, يلعبون, زي, خدمي, يستاهلوا, التشكيل, ال...  hate
# 3     [اداء, فاشل, طاقيه, اليوم, حسونا, بالاحباط, ال...  hate
# 4     [اداء, فاشل, خدمي, اليوم, حسونا, بالاحباط, الم...  hate
# ...                                                 ...   ...
# 3037  [مرة, ثانية, طاقيه, يحطمون, الآمال, لازم, حل, ...  hate
# 3039  [اخخ, يالقهر, دايم, اذا, خسر, الهلال, ابوي, يخ...  hate
# 3040                    [الفيصلي, بلا, كرامة, وخرب, شي]  hate
# 3041  [لربما, انك, الدوري, الاستثناي, كنت, مرتديا, ث...   not
# 3043  [باولينيو, باقي, وجه, تغرد, وجه, البومه, خبر, ...  hate
#
# [2316 rows x 3 columns]

# %%
# Export the cleaned DataFrame to a new CSV file
df.to_csv('AAAAA sports_tweets.csv', index=False)
